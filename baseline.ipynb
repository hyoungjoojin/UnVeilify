# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/AI_Project/project/GAN-based-face-mask-removal-version2
# Out:
# /content/drive/MyDrive/AI_Project/project/GAN-based-face-mask-removal-version2

# %% [markdown]
# ## The FaceG model encountered a shape mismatch error, so I modified the values arbitrarily. However, this could undermine the integrity of the baseline model. Moreover, these minor adjustments have continuously led to additional issues, making it challenging to continue training and testing with the baseline model.

# %% [markdown]
# kernel_initializer=self.initializer --> kernel_initializer=self.initializer(shape=(3, 3, 3, 32))

# %%
# !python main.py --mode train  # If a checkpoint exists, training proceeds from the latest checkpoint.
# Out:
# 2023-11-26 14:20:40.566111: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-26 14:20:40.566179: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-26 14:20:40.566210: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-26 14:20:40.573139: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python main.py --mode train --choice_ckpt --m_ckpt_num 'num' --f_ckpt_num 'num' --d_ckpt_num 'num'  # If you want to train at a specific checkpoint.

# %%
# !python main.py --mode test --test_path /content/drive/MyDrive/AI_Project/project/GAN-based-face-mask-removal-version2/test/test1.png # Make predictions from the latest checkpoints.
# Out:
# 2023-11-26 13:00:47.824766: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-26 13:00:47.824826: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-26 13:00:47.824875: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-26 13:00:47.830383: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
